# %%
a = 4
b = 9

if type (b) is no int:
  raise Expetion ( "El valor de b debe ser un numero entero")

  elif b

# %%
a = 90
b = 50
if a < b:
  print(a, "Es menor que", b)
   elif a > b:
    print(a, "Es mayor que", b)
  else:
      print(a, "Es igual que", b)
# Out:
#   File "/tmp/ipykernel_979/1776196911.py", line 5
#     elif a > b:
#     ^
# IndentationError: unexpected indent

# %%
a = int(input("Enter the first number"))
b = int(input("Enter the secod mumbre"))

if a < b:
  print(a, "Es menor que" b)

# %%
# Entrenando mi logica
a = int (input("Ingresar el primer numero"))
b = int (inpput("Ingresar el segundo nummero"))

if type (b)
